# %%
'''
# !pip install mediapipe
# !pip install seaborn
# !pip install tensorflow
# !pip install openpyxl
'''
# Out:
# '\n!pip install mediapipe\n!pip install seaborn\n!pip install tensorflow\n'

# %%
import mediapipe as mp
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import os
import shutil
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import glob
import cv2
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
np.random.seed(42)
#RUN

# %%
# Create a object from Holistic to detect (pose, face, and hands keypoints)
mp_holistic = mp.solutions.holistic
# Drawing utilities
mp_drawing = mp.solutions.drawing_utils

# %%
'''
The input image is converted from BGR to RGB because the MediaPipe model expects RGB images.
It sets image.flags.writeable to False before passing it to the model to prevent any unwanted modifications during the inference process.
The images will converted back from RGB to BGR for any further OpenCV operations,
this ensures the image can be processed further by OpenCV without any issues related to color formats.
'''

def mediapipe_detection(image, model):

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
'''
This function is responsible for drawing the detected landmarks on the image, allowing you to imagen the pose and hand landmarks detected by MediaPipe.

The function draws the pose landmarks, left hand landmarks, and right hand landmarks with different colors and styles.

color: Defines the color of the landmarks.
thickness: Defines how thick the lines connecting the landmarks will be.
circle_radius: Controls the radius of the circles around each landmark.

This will makes it easier to detected landmarks on the image for debugging or interpretation purposes.
'''

def draw_styled_landmarks(image, results):

    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
'''
This function adjusts the landmarks by centering them around a specific point LikeTHE ( the nose or wrist)
that's to normalize the positions and remove any translation shift in the data.

Reshape>> for thhe landmark array is reshaped to handle 3D points (x, y, z).

Centering>> Like (nose or wrist) is subtracted from each landmark to "center" the landmarks around the specific point.
It's look like Normalization :)
'''

def adjust_landmarks(arr,center):

    # Reshape the array to have shape (n, 3)
    arr_reshaped = arr.reshape(-1, 3)

    # Repeat the center array to have shape (n, 3)
    center_repeated = np.tile(center, (len(arr_reshaped), 1))

    # Subtract the center array from the arr array
    arr_adjusted = arr_reshaped - center_repeated

    # Reshape arr_adjusted back to shape (n*3,)
    arr_adjusted = arr_adjusted.reshape(-1)
    return(arr_adjusted)

# %%
'''
This function extracts and adjusts keypoints:
Pose, Left Hand, Right Hand Keypoints: Each set of landmarks (pose, left hand, right hand) is flattened into a 1D array.
Also the landmarks are adjusted by centering around specific points (nose for pose, wrists for hands).
So. it's to extract and adjust the keypoints for each frame, making them ready for further analysis or machine learning models.
'''

def extract_keypoints(results):

    pose = np.array([[res.x, res.y, res.z] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    nose=pose[:3]
    lh_wrist=lh[:3]
    rh_wrist=rh[:3]
    pose_adjusted = adjust_landmarks(pose,nose)
    lh_adjusted = adjust_landmarks(lh,lh_wrist)
    rh_adjusted = adjust_landmarks(rh,rh_wrist)
    return pose_adjusted, lh_adjusted, rh_adjusted

# %%
'''
I have to adjust the range to fit the words and numbers :) #############
'''
# RUN
# Define the different ranges that needed
ranges = [(1, 32), (71, 503)]  # (1, 32) represents numbers, (71, 503) represents Words

# Initialize an empty list to store the results
selected_words = []

# Iterate over each range
for start, end in ranges:
    # Extend the list with zero-padded numbers in the current range
    selected_words.extend([str(num).zfill(4) for num in range(start, end)])

# Print the result
print(selected_words)
# Out:
# ['0001', '0002', '0003', '0004', '0005', '0006', '0007', '0008', '0009', '0010', '0011', '0012', '0013', '0014', '0015', '0016', '0017', '0018', '0019', '0020', '0021', '0022', '0023', '0024', '0025', '0026', '0027', '0028', '0029', '0030', '0031', '0071', '0072', '0073', '0074', '0075', '0076', '0077', '0078', '0079', '0080', '0081', '0082', '0083', '0084', '0085', '0086', '0087', '0088', '0089', '0090', '0091', '0092', '0093', '0094', '0095', '0096', '0097', '0098', '0099', '0100', '0101', '0102', '0103', '0104', '0105', '0106', '0107', '0108', '0109', '0110', '0111', '0112', '0113', '0114', '0115', '0116', '0117', '0118', '0119', '0120', '0121', '0122', '0123', '0124', '0125', '0126', '0127', '0128', '0129', '0130', '0131', '0132', '0133', '0134', '0135', '0136', '0137', '0138', '0139', '0140', '0141', '0142', '0143', '0144', '0145', '0146', '0147', '0148', '0149', '0150', '0151', '0152', '0153', '0154', '0155', '0156', '0157', '0158', '0159', '0160', '0161', '0162', '0163', '0164', '0165', '0166', '0167', '0168', '0169', '0170', '0171', '0172', '0173', '0174', '0175', '0176', '0177', '0178', '0179', '0180', '0181', '0182', '0183', '0184', '0185', '0186', '0187', '0188', '0189', '0190', '0191', '0192', '0193', '0194', '0195', '0196', '0197', '0198', '0199', '0200', '0201', '0202', '0203', '0204', '0205', '0206', '0207', '0208', '0209', '0210', '0211', '0212', '0213', '0214', '0215', '0216', '0217', '0218', '0219', '0220', '0221', '0222', '0223', '0224', '0225', '0226', '0227', '0228', '0229', '0230', '0231', '0232', '0233', '0234', '0235', '0236', '0237', '0238', '0239', '0240', '0241', '0242', '0243', '0244', '0245', '0246', '0247', '0248', '0249', '0250', '0251', '0252', '0253', '0254', '0255', '0256', '0257', '0258', '0259', '0260', '0261', '0262', '0263', '0264', '0265', '0266', '0267', '0268', '0269', '0270', '0271', '0272', '0273', '0274', '0275', '0276', '0277', '0278', '0279', '0280', '0281', '0282', '0283', '0284', '0285', '0286', '0287', '0288', '0289', '0290', '0291', '0292', '0293', '0294', '0295', '0296', '0297', '0298', '0299', '0300', '0301', '0302', '0303', '0304', '0305', '0306', '0307', '0308', '0309', '0310', '0311', '0312', '0313', '0314', '0315', '0316', '0317', '0318', '0319', '0320', '0321', '0322', '0323', '0324', '0325', '0326', '0327', '0328', '0329', '0330', '0331', '0332', '0333', '0334', '0335', '0336', '0337', '0338', '0339', '0340', '0341', '0342', '0343', '0344', '0345', '0346', '0347', '0348', '0349', '0350', '0351', '0352', '0353', '0354', '0355', '0356', '0357', '0358', '0359', '0360', '0361', '0362', '0363', '0364', '0365', '0366', '0367', '0368', '0369', '0370', '0371', '0372', '0373', '0374', '0375', '0376', '0377', '0378', '0379', '0380', '0381', '0382', '0383', '0384', '0385', '0386', '0387', '0388', '0389', '0390', '0391', '0392', '0393', '0394', '0395', '0396', '0397', '0398', '0399', '0400', '0401', '0402', '0403', '0404', '0405', '0406', '0407', '0408', '0409', '0410', '0411', '0412', '0413', '0414', '0415', '0416', '0417', '0418', '0419', '0420', '0421', '0422', '0423', '0424', '0425', '0426', '0427', '0428', '0429', '0430', '0431', '0432', '0433', '0434', '0435', '0436', '0437', '0438', '0439', '0440', '0441', '0442', '0443', '0444', '0445', '0446', '0447', '0448', '0449', '0450', '0451', '0452', '0453', '0454', '0455', '0456', '0457', '0458', '0459', '0460', '0461', '0462', '0463', '0464', '0465', '0466', '0467', '0468', '0469', '0470', '0471', '0472', '0473', '0474', '0475', '0476', '0477', '0478', '0479', '0480', '0481', '0482', '0483', '0484', '0485', '0486', '0487', '0488', '0489', '0490', '0491', '0492', '0493', '0494', '0495', '0496', '0497', '0498', '0499', '0500', '0501', '0502']

# %%
'''
This function processes all the video frames of sign language sings for a particular signer and split (train, test, or val).
It does the following:

For each word, it processes video files.

For each frame in the video, the function:
>> Reads the frame.

>> Uses mediapipe_detection to detect landmarks.

>> Extracts the keypoints (pose, left hand, right hand).

>> Appends the keypoints to the respective lists.

>> After processing a video, the keypoints are saved as .npy files.


This function generates numpy arrays of keypoints for each video in the specified folder location.
Args:
    signer(int): the signer of interest. Could be 01 or 02 or 03
    split(str): can be 'train', 'test' or 'val'
'''
def make_keypoint_arrays(path,signer,split):

    os.makedirs('karsl-502',exist_ok = True)
    os.makedirs(f'karsl-502/{signer}',exist_ok = True)
    os.makedirs(f'karsl-502/{signer}/{split}',exist_ok = True)
    working_path = f'karsl-502/{signer}/{split}'
    words_folder = os.path.join(path,str(signer),str(signer), split)

    # Loop through all the subfolders in the folder
    for word in tqdm(selected_words):

        video_files = os.listdir(os.path.join(words_folder, word))
          # Loop through the video files
        for video_file in video_files:
                # Open the video file
            video = sorted(os.listdir(os.path.join(words_folder, word, video_file)))

            # Initialize the list of keypoints for this video
            pose_keypoints, lh_keypoints, rh_keypoints = [], [], []
            with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
              # Loop through the video frames
              for frame in video:
                  # Perform any necessary preprocessing on the frame (e.g., resizing, normalization)
                frame = os.path.join(words_folder, word, video_file,frame)
                frame = cv2.imread(frame)
#                 frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                  # Normalize pixel values to the range [0, 1]
                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Extract keypoints
                pose, lh, rh = extract_keypoints(results)
                # Add the keypoints to the list for this video
                pose_keypoints.append(pose)
                lh_keypoints.append(lh)
                rh_keypoints.append(rh)
                # Save the keypoints for this video to a numpy array
                pose_directory = os.path.join(working_path, word,'pose_keypoints')
                lh_directory = os.path.join(working_path, word,'lh_keypoints')
                rh_directory = os.path.join(working_path, word,'rh_keypoints')

                if not os.path.exists(pose_directory):
                    os.makedirs(pose_directory)

                if not os.path.exists(lh_directory):
                    os.makedirs(lh_directory)

                if not os.path.exists(rh_directory):
                    os.makedirs(rh_directory)

                pose_path = os.path.join(pose_directory, video_file)
                np.save(pose_path, pose_keypoints)

                lh_path = os.path.join(lh_directory, video_file)
                np.save(lh_path, lh_keypoints)

                rh_path = os.path.join(rh_directory, video_file)
                np.save(rh_path, rh_keypoints)

# %%
#make_keypoint_arrays('G:\Capstone data\karsl-502','01','train')
#make_keypoint_arrays('G:\Capstone data\karsl-502','01','test')
#make_keypoint_arrays('G:\Capstone data\karsl-502','02','train')
#make_keypoint_arrays('G:\Capstone data\karsl-502','02','test')
#make_keypoint_arrays('G:\Capstone data\karsl-502','03','train')
#make_keypoint_arrays('G:\Capstone data\karsl-502','03','test')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 463/463 [14:59:06<00:00, 116.52s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 463/463 [5:03:00<00:00, 39.27s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 463/463 [21:05:57<00:00, 164.05s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 463/463 [4:05:33<00:00, 31.82s/it]

# %%
# Load the sentences data
sentences_df = pd.read_excel('G:/Capstone data/Sentences.xlsx', sheet_name=None)

# Extract the sentences from each sheet
sentences = {}
for sheet_name, df in sentences_df.items():
    sentences[sheet_name] = df['Sentence'].tolist()

sentences
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sentence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 7
#       5 sentences = {}
#       6 for sheet_name, df in sentences_df.items():
# ----> 7     sentences[sheet_name] = df['Sentence'].tolist()
#       9 sentences
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Sentence'

# %% [markdown]
# To handle multiple words in a single instance, we’ll create a function to process multiple words (video files) and concatenate the sequences for each word in a sentence.

# %% [markdown]
# To collect sequences of words and combine them into a sentence,
# it's return sequences of keypoints for each sentence.

# %% [markdown]
# Sentence Construction: We split each sentence into words, process the video files for each word, and then concatenate them to form a complete sentence sequence.
#
# Return Sentence Sequences: We return the sentence sequences, where each sentence is represented by the concatenation of its word sequences.

# %% [markdown]
# **Sentence Construction**: We split each sentence into words, process the video files for each word, and then concatenate them to form a complete sentence sequence.
#
# **Return Sentence Sequences:** We return the sentence sequences, where each sentence is represented by the concatenation of its word sequences.

# %%
# def make_sentence_sequences(path, signer, split):
#     # This function now returns sequences for multiple words in a sentence
#     sentence_sequences = []  # Store sequences of keypoints for the entire sentence

#     words_folder = os.path.join(path, str(signer), str(signer), split)

#     for sentence in tqdm(karsl_6['Sign-Arabic']):
#         # Split sentence into individual words
#         words_in_sentence = sentence.split()

#         word_sequences = []  # To hold sequences for each word in the sentence

#         for word in words_in_sentence:
#             # Get word ID and find corresponding video files
#             word_id = w2id.get(word)
#             word_video_dir = os.path.join(words_folder, str(word_id).zfill(4))

#             if os.path.exists(word_video_dir):
#                 video_files = os.listdir(word_video_dir)

#                 for video_file in video_files:
#                     video_path = os.path.join(word_video_dir, video_file)
#                     keypoints_sequence = extract_keypoints_from_video(video_path)
#                     word_sequences.append(keypoints_sequence)

#         # Concatenate word sequences to form a sentence
#         sentence_sequence = np.concatenate(word_sequences, axis=0)
#         sentence_sequences.append(sentence_sequence)

#     return np.array(sentence_sequences)

# %% [markdown]
# Modifying the LSTM model slightly to accommodate sequences of multiple words for each sentence.

# %% [markdown]
# Input Shape: The model takes a sequence of keypoints (from multiple words), processes them through two LSTM layers, and then outputs a prediction for the sentence.

# %%
def build_lstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape))
    model.add(LSTM(128))  # Process the entire sentence as a sequence of words
    model.add(Dense(64, activation='relu'))  # Dense layer for hidden representation
    model.add(Dense(num_classes, activation='softmax'))  # Output layer for sentence prediction

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# Now need to format the input data (X) as sequences of keypoints for sentences, and output data (Y) as the corresponding one-hot encoded sentence labels.

# %% [markdown]
# X_data: Each sentence is represented by the concatenation of its word sequences.
#
# y_data: The sentence label is assigned using the label_map, which maps each sentence to an ID.

# %%
def prepare_data_for_lstm(data_path, signers, split, frame_interval=10):
    X_data, y_data = [], []

    for sentence in tqdm(karsl_6['Sign-Arabic']):
        # Skip non-string sentences
        if not isinstance(sentence, str):
            print(f"Skipping non-string value: {sentence}")
            continue  # Skip this iteration if sentence is not a string
        
        sentence_sequence = []  # Store sequences for this sentence
        sentence_labels = []  # Store labels for this sentence
        words_in_sentence = sentence.split()

        for word in words_in_sentence:
            word_id = w2id.get(word)
            if word_id is None:
                print(f"Word '{word}' not found in w2id dictionary. Skipping this word.")
                continue  # Skip if word is not in w2id
            
            word_video_dir = os.path.join(data_path, str(word_id).zfill(4))

            if os.path.exists(word_video_dir):
                word_sequences = []
                video_files = os.listdir(word_video_dir)

                for video_file in video_files:
                    video_path = os.path.join(word_video_dir, video_file)
                    keypoints_sequence = extract_keypoints_from_video(video_path, frame_interval)
                    word_sequences.append(keypoints_sequence)

                # Concatenate all word sequences into one word sequence
                sentence_sequence.append(np.concatenate(word_sequences, axis=0))
                
                # Retrieve and append the label for this word to the sentence's label list
                label = label_map.get(word)
                if label is not None:
                    sentence_labels.append(label)
                else:
                    print(f"Label for word '{word}' not found. Skipping this word's label.")
            else:
                print(f"Video data for word '{word}' not found at {word_video_dir}. Skipping this word.")

        # Only append to X_data and y_data if there are valid sequences and labels
        if sentence_sequence and sentence_labels:
            X_data.append(np.concatenate(sentence_sequence, axis=0))
            y_data.append(sentence_labels)  # Append the sentence's labels

    # Check if X_data or y_data are empty after processing
    if len(X_data) == 0 or len(y_data) == 0:
        print("Error: No valid data found after processing!")
        return np.array([]), np.array([])  # Return empty arrays if no data

    # Convert y_data to a numpy array with one-hot encoding
    y_data = np.array([to_categorical(labels) for labels in y_data])

    return np.array(X_data), y_data

# %% [markdown]
# Training: We split the data into training and validation sets to evaluate the model's performance.
#
# Testing: We also prepare a test set to evaluate the final performance after training.

# %%
X_train, y_train = prepare_data_for_lstm(data_path, ['01', '02'], 'train', frame_interval=10)

# Ensure data is not empty before proceeding with the split
if X_train.size == 0 or y_train.size == 0:
    print("Error: Empty training data. Please check the input data.")
else:
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    print(f'X_train shape: {X_train.shape}')
    print(f'y_train shape: {y_train.shape}')
    print(f'X_val shape: {X_val.shape}')
    print(f'y_val shape: {y_val.shape}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 463/463 [00:00<00:00, 8111.15it/s]
# Skipping non-string value: 0
# Skipping non-string value: 1
# Skipping non-string value: 2
# Skipping non-string value: 3
# Skipping non-string value: 4
# Skipping non-string value: 5
# Skipping non-string value: 6
# Skipping non-string value: 7
# Skipping non-string value: 8
# Skipping non-string value: 9
# Skipping non-string value: 10
# Skipping non-string value: 20
# Skipping non-string value: 30
# Skipping non-string value: 40
# Skipping non-string value: 50
# Skipping non-string value: 60
# Skipping non-string value: 70
# Skipping non-string value: 80
# Skipping non-string value: 90
# Skipping non-string value: 100
# Skipping non-string value: 200
# Skipping non-string value: 300
# Skipping non-string value: 400
# Skipping non-string value: 500
# Skipping non-string value: 600
# Skipping non-string value: 700
# Skipping non-string value: 800
# Skipping non-string value: 900
# Skipping non-string value: 1000
# Skipping non-string value: 1000000
# Skipping non-string value: 10000000
# Word 'هيكل' not found in w2id dictionary. Skipping this word.
# Word 'عظمي' not found in w2id dictionary. Skipping this word.
# Video data for word 'جمجة' not found at G:\Capstone data\karsl-502\0072. Skipping this word.
# Word 'عمود' not found in w2id dictionary. Skipping this word.
# Word 'فقري' not found in w2id dictionary. Skipping this word.
# Word 'قفص' not found in w2id dictionary. Skipping this word.
# Word 'صدري' not found in w2id dictionary. Skipping this word.
# Word 'جهاز' not found in w2id dictionary. Skipping this word.
# Word 'تنفسي' not found in w2id dictionary. Skipping this word.
# Word 'قصبة' not found in w2id dictionary. Skipping this word.
# Word 'هوائية' not found in w2id dictionary. Skipping this word.
# Video data for word 'رئتان' not found at G:\Capstone data\karsl-502\0077. Skipping this word.
# Word 'شهيق' not found in w2id dictionary. Skipping this word.
# Word '-' not found in w2id dictionary. Skipping this word.
# Word 'زفير' not found in w2id dictionary. Skipping this word.
# Word 'جهاز' not found in w2id dictionary. Skipping this word.
# Word 'هضمي' not found in w2id dictionary. Skipping this word.
# Video data for word 'وجه' not found at G:\Capstone data\karsl-502\0080. Skipping this word.
# Video data for word 'بلعوم' not found at G:\Capstone data\karsl-502\0081. Skipping this word.
# Video data for word 'كبد' not found at G:\Capstone data\karsl-502\0082. Skipping this word.
# Video data for word 'البنكرياس' not found at G:\Capstone data\karsl-502\0083. Skipping this word.
# Word 'الأمعاء' not found in w2id dictionary. Skipping this word.
# Word 'الدقيقة' not found in w2id dictionary. Skipping this word.
# Word 'الأمعاء' not found in w2id dictionary. Skipping this word.
# Word 'الغليظة' not found in w2id dictionary. Skipping this word.
# Word 'الزائدة' not found in w2id dictionary. Skipping this word.
# Word 'الدودية' not found in w2id dictionary. Skipping this word.
# Word 'جهاز' not found in w2id dictionary. Skipping this word.
# Word 'عصبي' not found in w2id dictionary. Skipping this word.
# Video data for word 'قلب' not found at G:\Capstone data\karsl-502\0088. Skipping this word.
# Word 'حواس' not found in w2id dictionary. Skipping this word.
# Word 'خمس' not found in w2id dictionary. Skipping this word.
# Video data for word 'عضلة' not found at G:\Capstone data\karsl-502\0090. Skipping this word.
# Video data for word 'أنسجة' not found at G:\Capstone data\karsl-502\0091. Skipping this word.
# Video data for word 'مستشفى' not found at G:\Capstone data\karsl-502\0092. Skipping this word.
# Word 'إسعافات' not found in w2id dictionary. Skipping this word.
# Word 'أولية' not found in w2id dictionary. Skipping this word.
# Word 'جرح' not found in w2id dictionary. Skipping this word.
# Word 'نازف' not found in w2id dictionary. Skipping this word.
# Video data for word 'حروق' not found at G:\Capstone data\karsl-502\0095. Skipping this word.
# Word 'مخدر/' not found in w2id dictionary. Skipping this word.
# Word 'بنج' not found in w2id dictionary. Skipping this word.
# Word 'عملية' not found in w2id dictionary. Skipping this word.
# Word 'جراحية' not found in w2id dictionary. Skipping this word.
# Word 'شاش' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'ضمادة' not found in w2id dictionary. Skipping this word.
# Word 'شريط' not found in w2id dictionary. Skipping this word.
# Word 'لاصق' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'بلاستر' not found in w2id dictionary. Skipping this word.
# Video data for word 'صيدلية' not found at G:\Capstone data\karsl-502\0100. Skipping this word.
# Word 'تحليل' not found in w2id dictionary. Skipping this word.
# Word 'دم' not found in w2id dictionary. Skipping this word.
# Word 'فحص' not found in w2id dictionary. Skipping this word.
# Word 'سريري' not found in w2id dictionary. Skipping this word.
# Word 'فحص' not found in w2id dictionary. Skipping this word.
# Word 'النظر' not found in w2id dictionary. Skipping this word.
# Word 'ميزان' not found in w2id dictionary. Skipping this word.
# Word 'حرارة' not found in w2id dictionary. Skipping this word.
# Word 'سماعة' not found in w2id dictionary. Skipping this word.
# Word 'أذن' not found in w2id dictionary. Skipping this word.
# Word 'جهاز' not found in w2id dictionary. Skipping this word.
# Word 'قياس' not found in w2id dictionary. Skipping this word.
# Word 'الضغط' not found in w2id dictionary. Skipping this word.
# Word 'نبض' not found in w2id dictionary. Skipping this word.
# Word 'القلب' not found in w2id dictionary. Skipping this word.
# Word 'تحليل' not found in w2id dictionary. Skipping this word.
# Word 'طبي' not found in w2id dictionary. Skipping this word.
# Word 'معمل' not found in w2id dictionary. Skipping this word.
# Word 'التحاليل' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'مختبر' not found in w2id dictionary. Skipping this word.
# Word 'صورة' not found in w2id dictionary. Skipping this word.
# Word 'اشعة' not found in w2id dictionary. Skipping this word.
# Video data for word 'التهاب' not found at G:\Capstone data\karsl-502\0111. Skipping this word.
# Video data for word 'تورم' not found at G:\Capstone data\karsl-502\0112. Skipping this word.
# Video data for word 'زكام' not found at G:\Capstone data\karsl-502\0113. Skipping this word.
# Video data for word 'عدوى' not found at G:\Capstone data\karsl-502\0114. Skipping this word.
# Video data for word 'صداع' not found at G:\Capstone data\karsl-502\0115. Skipping this word.
# Video data for word 'ألم' not found at G:\Capstone data\karsl-502\0116. Skipping this word.
# Video data for word 'حمى' not found at G:\Capstone data\karsl-502\0117. Skipping this word.
# Video data for word 'إسهال' not found at G:\Capstone data\karsl-502\0118. Skipping this word.
# Video data for word 'إمساك' not found at G:\Capstone data\karsl-502\0119. Skipping this word.
# Video data for word 'مغص' not found at G:\Capstone data\karsl-502\0120. Skipping this word.
# Word 'مرض' not found in w2id dictionary. Skipping this word.
# Word 'السكر' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'سكري' not found in w2id dictionary. Skipping this word.
# Word 'أزمة' not found in w2id dictionary. Skipping this word.
# Word 'قلبية' not found in w2id dictionary. Skipping this word.
# Video data for word 'سرطان' not found at G:\Capstone data\karsl-502\0123. Skipping this word.
# Word 'مرض' not found in w2id dictionary. Skipping this word.
# Word 'فقدان' not found in w2id dictionary. Skipping this word.
# Word 'المناعة' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'الإيدز' not found in w2id dictionary. Skipping this word.
# Word 'تساقط' not found in w2id dictionary. Skipping this word.
# Word 'الشعر' not found in w2id dictionary. Skipping this word.
# Word 'سكتة' not found in w2id dictionary. Skipping this word.
# Word 'قلبية' not found in w2id dictionary. Skipping this word.
# Word 'شلل' not found in w2id dictionary. Skipping this word.
# Word 'نصفي' not found in w2id dictionary. Skipping this word.
# Word 'شلل' not found in w2id dictionary. Skipping this word.
# Word 'دماغي' not found in w2id dictionary. Skipping this word.
# Word 'ضغط' not found in w2id dictionary. Skipping this word.
# Word 'الدم' not found in w2id dictionary. Skipping this word.
# Video data for word 'حساسية' not found at G:\Capstone data\karsl-502\0130. Skipping this word.
# Word 'حكة' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'هرش' not found in w2id dictionary. Skipping this word.
# Video data for word 'دواء' not found at G:\Capstone data\karsl-502\0132. Skipping this word.
# Word 'دورة' not found in w2id dictionary. Skipping this word.
# Word 'شهرية' not found in w2id dictionary. Skipping this word.
# Word 'مريض' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'مرض' not found in w2id dictionary. Skipping this word.
# Video data for word 'كبسولة' not found at G:\Capstone data\karsl-502\0135. Skipping this word.
# Video data for word 'دواء' not found at G:\Capstone data\karsl-502\0132. Skipping this word.
# Word 'شراب' not found in w2id dictionary. Skipping this word.
# Video data for word 'مرهم' not found at G:\Capstone data\karsl-502\0137. Skipping this word.
# Video data for word 'قطارة' not found at G:\Capstone data\karsl-502\0138. Skipping this word.
# Word 'أخذ' not found in w2id dictionary. Skipping this word.
# Word 'إبرة' not found in w2id dictionary. Skipping this word.
# Video data for word 'تلقيح' not found at G:\Capstone data\karsl-502\0140. Skipping this word.
# Video data for word 'تطعيم' not found at G:\Capstone data\karsl-502\0141. Skipping this word.
# Word 'أشعة' not found in w2id dictionary. Skipping this word.
# Word 'ليزر' not found in w2id dictionary. Skipping this word.
# Video data for word 'مخدرات' not found at G:\Capstone data\karsl-502\0143. Skipping this word.
# Video data for word 'إدمان' not found at G:\Capstone data\karsl-502\0144. Skipping this word.
# Word 'توحد' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'أوتيزم' not found in w2id dictionary. Skipping this word.
# Video data for word 'منغولي' not found at G:\Capstone data\karsl-502\0146. Skipping this word.
# Video data for word 'بكتريا' not found at G:\Capstone data\karsl-502\0147. Skipping this word.
# Video data for word 'جرثومة' not found at G:\Capstone data\karsl-502\0148. Skipping this word.
# Video data for word 'فيروس' not found at G:\Capstone data\karsl-502\0149. Skipping this word.
# Video data for word 'إنتشار' not found at G:\Capstone data\karsl-502\0150. Skipping this word.
# Video data for word 'إعاقة' not found at G:\Capstone data\karsl-502\0151. Skipping this word.
# Video data for word 'إعاقة' not found at G:\Capstone data\karsl-502\0151. Skipping this word.
# Word 'ذهنية' not found in w2id dictionary. Skipping this word.
# Word 'اعاقة' not found in w2id dictionary. Skipping this word.
# Word 'جسدية' not found in w2id dictionary. Skipping this word.
# Word 'اعاقة' not found in w2id dictionary. Skipping this word.
# Word 'بصرية' not found in w2id dictionary. Skipping this word.
# Video data for word 'إعاقة' not found at G:\Capstone data\karsl-502\0151. Skipping this word.
# Word 'سمعية' not found in w2id dictionary. Skipping this word.
# Video data for word 'وباء' not found at G:\Capstone data\karsl-502\0156. Skipping this word.
# Video data for word 'مناعة' not found at G:\Capstone data\karsl-502\0157. Skipping this word.
# Video data for word 'عصب' not found at G:\Capstone data\karsl-502\0158. Skipping this word.
# Video data for word 'معافى' not found at G:\Capstone data\karsl-502\0159. Skipping this word.
# Video data for word 'يأكل' not found at G:\Capstone data\karsl-502\0160. Skipping this word.
# Video data for word 'يشرب' not found at G:\Capstone data\karsl-502\0161. Skipping this word.
# Video data for word 'ينام' not found at G:\Capstone data\karsl-502\0162. Skipping this word.
# Video data for word 'يستيقظ' not found at G:\Capstone data\karsl-502\0163. Skipping this word.
# Video data for word 'يسمع' not found at G:\Capstone data\karsl-502\0164. Skipping this word.
# Video data for word 'يسكت' not found at G:\Capstone data\karsl-502\0165. Skipping this word.
# Video data for word 'يشم' not found at G:\Capstone data\karsl-502\0166. Skipping this word.
# Video data for word 'يصعد' not found at G:\Capstone data\karsl-502\0167. Skipping this word.
# Video data for word 'ينزل' not found at G:\Capstone data\karsl-502\0168. Skipping this word.
# Video data for word 'يفتح' not found at G:\Capstone data\karsl-502\0169. Skipping this word.
# Word 'يقفل' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'يغلق' not found in w2id dictionary. Skipping this word.
# Word ')' not found in w2id dictionary. Skipping this word.
# Video data for word 'يبني' not found at G:\Capstone data\karsl-502\0171. Skipping this word.
# Video data for word 'يكسر' not found at G:\Capstone data\karsl-502\0172. Skipping this word.
# Video data for word 'يمشي' not found at G:\Capstone data\karsl-502\0173. Skipping this word.
# Video data for word 'يحب' not found at G:\Capstone data\karsl-502\0174. Skipping this word.
# Video data for word 'يكره' not found at G:\Capstone data\karsl-502\0175. Skipping this word.
# Video data for word 'يشوي' not found at G:\Capstone data\karsl-502\0176. Skipping this word.
# Video data for word 'يحرث' not found at G:\Capstone data\karsl-502\0177. Skipping this word.
# Video data for word 'يزرع' not found at G:\Capstone data\karsl-502\0178. Skipping this word.
# Video data for word 'يسقي' not found at G:\Capstone data\karsl-502\0179. Skipping this word.
# Video data for word 'يحصد' not found at G:\Capstone data\karsl-502\0180. Skipping this word.
# Video data for word 'يفكر' not found at G:\Capstone data\karsl-502\0181. Skipping this word.
# Video data for word 'يساعد' not found at G:\Capstone data\karsl-502\0182. Skipping this word.
# Video data for word 'يدخن' not found at G:\Capstone data\karsl-502\0183. Skipping this word.
# Video data for word 'يدعم' not found at G:\Capstone data\karsl-502\0184. Skipping this word.
# Video data for word 'يختار' not found at G:\Capstone data\karsl-502\0185. Skipping this word.
# Video data for word 'ينادي' not found at G:\Capstone data\karsl-502\0186. Skipping this word.
# Video data for word 'يتنامى' not found at G:\Capstone data\karsl-502\0187. Skipping this word.
# Video data for word 'يصبغ' not found at G:\Capstone data\karsl-502\0188. Skipping this word.
# Video data for word 'يقف' not found at G:\Capstone data\karsl-502\0189. Skipping this word.
# Video data for word 'يستحم' not found at G:\Capstone data\karsl-502\0190. Skipping this word.
# Video data for word 'يدخل' not found at G:\Capstone data\karsl-502\0191. Skipping this word.
# Video data for word 'أسرة' not found at G:\Capstone data\karsl-502\0192. Skipping this word.
# Video data for word 'جدة' not found at G:\Capstone data\karsl-502\0193. Skipping this word.
# Video data for word 'جد' not found at G:\Capstone data\karsl-502\0194. Skipping this word.
# Video data for word 'أب' not found at G:\Capstone data\karsl-502\0195. Skipping this word.
# Video data for word 'أم' not found at G:\Capstone data\karsl-502\0196. Skipping this word.
# Video data for word 'أخت' not found at G:\Capstone data\karsl-502\0197. Skipping this word.
# Video data for word 'أخ' not found at G:\Capstone data\karsl-502\0198. Skipping this word.
# Video data for word 'بنت' not found at G:\Capstone data\karsl-502\0199. Skipping this word.
# Video data for word 'رضيع' not found at G:\Capstone data\karsl-502\0200. Skipping this word.
# Video data for word 'توأم' not found at G:\Capstone data\karsl-502\0201. Skipping this word.
# Video data for word 'رجل' not found at G:\Capstone data\karsl-502\0202. Skipping this word.
# Video data for word 'شاب' not found at G:\Capstone data\karsl-502\0203. Skipping this word.
# Video data for word 'شابة' not found at G:\Capstone data\karsl-502\0204. Skipping this word.
# Video data for word 'حفيد' not found at G:\Capstone data\karsl-502\0205. Skipping this word.
# Video data for word 'زواج' not found at G:\Capstone data\karsl-502\0206. Skipping this word.
# Video data for word 'حمل' not found at G:\Capstone data\karsl-502\0207. Skipping this word.
# Video data for word 'ولادة' not found at G:\Capstone data\karsl-502\0208. Skipping this word.
# Video data for word 'عم' not found at G:\Capstone data\karsl-502\0209. Skipping this word.
# Video data for word 'عمة' not found at G:\Capstone data\karsl-502\0210. Skipping this word.
# Video data for word 'خال' not found at G:\Capstone data\karsl-502\0211. Skipping this word.
# Video data for word 'خالة' not found at G:\Capstone data\karsl-502\0212. Skipping this word.
# Video data for word 'ابن' not found at G:\Capstone data\karsl-502\0216. Skipping this word.
# Word 'الأخ' not found in w2id dictionary. Skipping this word.
# Video data for word 'ابن' not found at G:\Capstone data\karsl-502\0216. Skipping this word.
# Word 'الأخت' not found in w2id dictionary. Skipping this word.
# Video data for word 'ابن' not found at G:\Capstone data\karsl-502\0216. Skipping this word.
# Word 'العم' not found in w2id dictionary. Skipping this word.
# Video data for word 'ابن' not found at G:\Capstone data\karsl-502\0216. Skipping this word.
# Video data for word 'ابنة' not found at G:\Capstone data\karsl-502\0217. Skipping this word.
# Video data for word 'ناس' not found at G:\Capstone data\karsl-502\0218. Skipping this word.
# Video data for word 'طلاق' not found at G:\Capstone data\karsl-502\0219. Skipping this word.
# Video data for word 'خطوبة' not found at G:\Capstone data\karsl-502\0220. Skipping this word.
# Video data for word 'حفلة' not found at G:\Capstone data\karsl-502\0221. Skipping this word.
# Video data for word 'وفاة' not found at G:\Capstone data\karsl-502\0222. Skipping this word.
# Video data for word 'طفل' not found at G:\Capstone data\karsl-502\0223. Skipping this word.
# Video data for word 'جميل' not found at G:\Capstone data\karsl-502\0224. Skipping this word.
# Video data for word 'قبيح' not found at G:\Capstone data\karsl-502\0225. Skipping this word.
# Video data for word 'طويل' not found at G:\Capstone data\karsl-502\0226. Skipping this word.
# Video data for word 'قصير' not found at G:\Capstone data\karsl-502\0227. Skipping this word.
# Video data for word 'نحيف' not found at G:\Capstone data\karsl-502\0228. Skipping this word.
# Video data for word 'سمين' not found at G:\Capstone data\karsl-502\0229. Skipping this word.
# Video data for word 'غني' not found at G:\Capstone data\karsl-502\0230. Skipping this word.
# Video data for word 'فقير' not found at G:\Capstone data\karsl-502\0231. Skipping this word.
# Video data for word 'محبط' not found at G:\Capstone data\karsl-502\0232. Skipping this word.
# Video data for word 'مشمئز' not found at G:\Capstone data\karsl-502\0233. Skipping this word.
# Video data for word 'مرتبك' not found at G:\Capstone data\karsl-502\0234. Skipping this word.
# Video data for word 'قلق' not found at G:\Capstone data\karsl-502\0235. Skipping this word.
# Video data for word 'مشوش' not found at G:\Capstone data\karsl-502\0236. Skipping this word.
# Video data for word 'خائف' not found at G:\Capstone data\karsl-502\0237. Skipping this word.
# Word 'سعيد' not found in w2id dictionary. Skipping this word.
# Word '(مسرور)' not found in w2id dictionary. Skipping this word.
# Video data for word 'حزين' not found at G:\Capstone data\karsl-502\0239. Skipping this word.
# Video data for word 'شجاع' not found at G:\Capstone data\karsl-502\0240. Skipping this word.
# Video data for word 'جبان' not found at G:\Capstone data\karsl-502\0241. Skipping this word.
# Video data for word 'طموح' not found at G:\Capstone data\karsl-502\0242. Skipping this word.
# Video data for word 'معجب' not found at G:\Capstone data\karsl-502\0243. Skipping this word.
# Word 'غائر' not found in w2id dictionary. Skipping this word.
# Word 'من' not found in w2id dictionary. Skipping this word.
# Word 'غائر' not found in w2id dictionary. Skipping this word.
# Word 'على' not found in w2id dictionary. Skipping this word.
# Video data for word 'ودود' not found at G:\Capstone data\karsl-502\0246. Skipping this word.
# Video data for word 'كريم' not found at G:\Capstone data\karsl-502\0247. Skipping this word.
# Video data for word 'بخيل' not found at G:\Capstone data\karsl-502\0248. Skipping this word.
# Video data for word 'طماع' not found at G:\Capstone data\karsl-502\0249. Skipping this word.
# Video data for word 'كذاب' not found at G:\Capstone data\karsl-502\0250. Skipping this word.
# Video data for word 'أناني' not found at G:\Capstone data\karsl-502\0251. Skipping this word.
# Video data for word 'متكبر' not found at G:\Capstone data\karsl-502\0252. Skipping this word.
# Video data for word 'متواضع' not found at G:\Capstone data\karsl-502\0253. Skipping this word.
# Video data for word 'شعور' not found at G:\Capstone data\karsl-502\0254. Skipping this word.
# Video data for word 'تعب' not found at G:\Capstone data\karsl-502\0255. Skipping this word.
# Video data for word 'بكاء' not found at G:\Capstone data\karsl-502\0256. Skipping this word.
# Video data for word 'احتقار' not found at G:\Capstone data\karsl-502\0257. Skipping this word.
# Word 'اعتماد' not found in w2id dictionary. Skipping this word.
# Word 'على' not found in w2id dictionary. Skipping this word.
# Word 'الذات' not found in w2id dictionary. Skipping this word.
# Video data for word 'خفيف' not found at G:\Capstone data\karsl-502\0259. Skipping this word.
# Video data for word 'ثقيل' not found at G:\Capstone data\karsl-502\0260. Skipping this word.
# Video data for word 'قديم' not found at G:\Capstone data\karsl-502\0261. Skipping this word.
# Video data for word 'حسد' not found at G:\Capstone data\karsl-502\0262. Skipping this word.
# Video data for word 'صدق' not found at G:\Capstone data\karsl-502\0263. Skipping this word.
# Video data for word 'غدر' not found at G:\Capstone data\karsl-502\0264. Skipping this word.
# Video data for word 'صبر' not found at G:\Capstone data\karsl-502\0265. Skipping this word.
# Video data for word 'لوم' not found at G:\Capstone data\karsl-502\0266. Skipping this word.
# Video data for word 'الحق' not found at G:\Capstone data\karsl-502\0267. Skipping this word.
# Video data for word 'خيانة' not found at G:\Capstone data\karsl-502\0268. Skipping this word.
# Video data for word 'إيثار' not found at G:\Capstone data\karsl-502\0269. Skipping this word.
# Video data for word 'تضحية' not found at G:\Capstone data\karsl-502\0270. Skipping this word.
# Video data for word 'شفقة' not found at G:\Capstone data\karsl-502\0271. Skipping this word.
# Video data for word 'ذكي' not found at G:\Capstone data\karsl-502\0272. Skipping this word.
# Video data for word 'أمام' not found at G:\Capstone data\karsl-502\0273. Skipping this word.
# Video data for word 'بجانب' not found at G:\Capstone data\karsl-502\0274. Skipping this word.
# Video data for word 'بعيد' not found at G:\Capstone data\karsl-502\0275. Skipping this word.
# Video data for word 'بين' not found at G:\Capstone data\karsl-502\0276. Skipping this word.
# Video data for word 'تحت' not found at G:\Capstone data\karsl-502\0277. Skipping this word.
# Video data for word 'حول' not found at G:\Capstone data\karsl-502\0278. Skipping this word.
# Video data for word 'خارج' not found at G:\Capstone data\karsl-502\0279. Skipping this word.
# Video data for word 'خلف' not found at G:\Capstone data\karsl-502\0280. Skipping this word.
# Video data for word 'داخل' not found at G:\Capstone data\karsl-502\0281. Skipping this word.
# Video data for word 'فوق' not found at G:\Capstone data\karsl-502\0282. Skipping this word.
# Video data for word 'قريب' not found at G:\Capstone data\karsl-502\0283. Skipping this word.
# Word 'من' not found in w2id dictionary. Skipping this word.
# Word 'خلال' not found in w2id dictionary. Skipping this word.
# Video data for word 'هنا' not found at G:\Capstone data\karsl-502\0285. Skipping this word.
# Video data for word 'هناك' not found at G:\Capstone data\karsl-502\0286. Skipping this word.
# Video data for word 'يسار' not found at G:\Capstone data\karsl-502\0287. Skipping this word.
# Video data for word 'يمين' not found at G:\Capstone data\karsl-502\0288. Skipping this word.
# Word 'أهلا' not found in w2id dictionary. Skipping this word.
# Word 'وسهلاً' not found in w2id dictionary. Skipping this word.
# Word 'السلام' not found in w2id dictionary. Skipping this word.
# Word 'عليكم' not found in w2id dictionary. Skipping this word.
# Video data for word 'تفضل' not found at G:\Capstone data\karsl-502\0291. Skipping this word.
# Video data for word 'جار' not found at G:\Capstone data\karsl-502\0292. Skipping this word.
# Video data for word 'شكراً' not found at G:\Capstone data\karsl-502\0293. Skipping this word.
# Video data for word 'صديق' not found at G:\Capstone data\karsl-502\0294. Skipping this word.
# Video data for word 'ضيف' not found at G:\Capstone data\karsl-502\0295. Skipping this word.
# Video data for word 'عدو' not found at G:\Capstone data\karsl-502\0296. Skipping this word.
# Video data for word 'عيب' not found at G:\Capstone data\karsl-502\0297. Skipping this word.
# Video data for word 'هدية' not found at G:\Capstone data\karsl-502\0298. Skipping this word.
# Video data for word 'بيت' not found at G:\Capstone data\karsl-502\0299. Skipping this word.
# Video data for word 'جدار' not found at G:\Capstone data\karsl-502\0300. Skipping this word.
# Video data for word 'سقف' not found at G:\Capstone data\karsl-502\0301. Skipping this word.
# Video data for word 'باب' not found at G:\Capstone data\karsl-502\0302. Skipping this word.
# Video data for word 'شباك' not found at G:\Capstone data\karsl-502\0303. Skipping this word.
# Video data for word 'غرفة' not found at G:\Capstone data\karsl-502\0304. Skipping this word.
# Video data for word 'غرفة' not found at G:\Capstone data\karsl-502\0304. Skipping this word.
# Word 'نوم' not found in w2id dictionary. Skipping this word.
# Video data for word 'سرير' not found at G:\Capstone data\karsl-502\0306. Skipping this word.
# Word 'مرتبة' not found in w2id dictionary. Skipping this word.
# Video data for word 'سرير' not found at G:\Capstone data\karsl-502\0306. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'حشية)' not found in w2id dictionary. Skipping this word.
# Word 'شرشف' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'غطاء' not found in w2id dictionary. Skipping this word.
# Word 'سرير)' not found in w2id dictionary. Skipping this word.
# Word 'وسادة' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'مخدة)' not found in w2id dictionary. Skipping this word.
# Word 'شماعة' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'مشجب)' not found in w2id dictionary. Skipping this word.
# Word 'خزانة' not found in w2id dictionary. Skipping this word.
# Word 'ملابس' not found in w2id dictionary. Skipping this word.
# Video data for word 'مطبخ' not found at G:\Capstone data\karsl-502\0312. Skipping this word.
# Word 'فرن' not found in w2id dictionary. Skipping this word.
# Word 'غازي' not found in w2id dictionary. Skipping this word.
# Word 'بوتاغاز' not found in w2id dictionary. Skipping this word.
# Word '(طابخ)' not found in w2id dictionary. Skipping this word.
# Word 'طبق' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'صحن)' not found in w2id dictionary. Skipping this word.
# Video data for word 'سكين' not found at G:\Capstone data\karsl-502\0316. Skipping this word.
# Video data for word 'شوكة' not found at G:\Capstone data\karsl-502\0317. Skipping this word.
# Video data for word 'ملعقة' not found at G:\Capstone data\karsl-502\0318. Skipping this word.
# Video data for word 'فنجان' not found at G:\Capstone data\karsl-502\0319. Skipping this word.
# Word 'مجمد' not found in w2id dictionary. Skipping this word.
# Word '(فريزر)' not found in w2id dictionary. Skipping this word.
# Word 'كأس' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'كوب)' not found in w2id dictionary. Skipping this word.
# Word 'حافظ' not found in w2id dictionary. Skipping this word.
# Word 'حرارة' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'ترمس)' not found in w2id dictionary. Skipping this word.
# Video data for word 'غرفة' not found at G:\Capstone data\karsl-502\0304. Skipping this word.
# Word 'طعام' not found in w2id dictionary. Skipping this word.
# Video data for word 'إبريق' not found at G:\Capstone data\karsl-502\0324. Skipping this word.
# Video data for word 'طاولة' not found at G:\Capstone data\karsl-502\0325. Skipping this word.
# Word 'كنكة' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'دلة)' not found in w2id dictionary. Skipping this word.
# Word 'دورة' not found in w2id dictionary. Skipping this word.
# Word 'مياه' not found in w2id dictionary. Skipping this word.
# Word '(حمام)' not found in w2id dictionary. Skipping this word.
# Video data for word 'كرسي' not found at G:\Capstone data\karsl-502\0328. Skipping this word.
# Video data for word 'غسالة' not found at G:\Capstone data\karsl-502\0329. Skipping this word.
# Video data for word 'منشفة' not found at G:\Capstone data\karsl-502\0330. Skipping this word.
# Word 'سجادة' not found in w2id dictionary. Skipping this word.
# Word '(زربية)' not found in w2id dictionary. Skipping this word.
# Word 'موكيت' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'فرش' not found in w2id dictionary. Skipping this word.
# Word 'أرضي)' not found in w2id dictionary. Skipping this word.
# Word 'moquette' not found in w2id dictionary. Skipping this word.
# Word 'ثريا' not found in w2id dictionary. Skipping this word.
# Word '(نجفة)' not found in w2id dictionary. Skipping this word.
# Video data for word 'مسجل' not found at G:\Capstone data\karsl-502\0334. Skipping this word.
# Word 'شريط' not found in w2id dictionary. Skipping this word.
# Word 'كاست' not found in w2id dictionary. Skipping this word.
# Word 'تلفزيون' not found in w2id dictionary. Skipping this word.
# Word '(تلفاز)' not found in w2id dictionary. Skipping this word.
# Word 'طبق' not found in w2id dictionary. Skipping this word.
# Word 'هوائي' not found in w2id dictionary. Skipping this word.
# Word '(دش)' not found in w2id dictionary. Skipping this word.
# Word 'شريط' not found in w2id dictionary. Skipping this word.
# Video data for word 'فيديو' not found at G:\Capstone data\karsl-502\0343. Skipping this word.
# Word 'كاميرا' not found in w2id dictionary. Skipping this word.
# Video data for word 'فيديو' not found at G:\Capstone data\karsl-502\0343. Skipping this word.
# Word 'كاميرا' not found in w2id dictionary. Skipping this word.
# Word 'فوتوغرافية' not found in w2id dictionary. Skipping this word.
# Word 'هاتف' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'تلفون)' not found in w2id dictionary. Skipping this word.
# Video data for word 'غرفة' not found at G:\Capstone data\karsl-502\0304. Skipping this word.
# Word 'ضيوف' not found in w2id dictionary. Skipping this word.
# Video data for word 'فيديو' not found at G:\Capstone data\karsl-502\0343. Skipping this word.
# Video data for word 'مبخرة' not found at G:\Capstone data\karsl-502\0344. Skipping this word.
# Video data for word 'مدفأة' not found at G:\Capstone data\karsl-502\0345. Skipping this word.
# Video data for word 'مفتاح' not found at G:\Capstone data\karsl-502\0346. Skipping this word.
# Video data for word 'مروحة' not found at G:\Capstone data\karsl-502\0347. Skipping this word.
# Word 'تدفئة' not found in w2id dictionary. Skipping this word.
# Word 'مركزية' not found in w2id dictionary. Skipping this word.
# Video data for word 'كهرباء' not found at G:\Capstone data\karsl-502\0349. Skipping this word.
# Video data for word 'مكيف' not found at G:\Capstone data\karsl-502\0350. Skipping this word.
# Word 'سلك' not found in w2id dictionary. Skipping this word.
# Word 'كهربائي' not found in w2id dictionary. Skipping this word.
# Word 'قابس' not found in w2id dictionary. Skipping this word.
# Word 'كهربائي' not found in w2id dictionary. Skipping this word.
# Word '(' not found in w2id dictionary. Skipping this word.
# Word 'فيش)' not found in w2id dictionary. Skipping this word.
# Word 'حقيبة' not found in w2id dictionary. Skipping this word.
# Word 'سفر' not found in w2id dictionary. Skipping this word.
# Video data for word 'مكواة' not found at G:\Capstone data\karsl-502\0354. Skipping this word.
# Word 'ميزان' not found in w2id dictionary. Skipping this word.
# Word 'حرارة' not found in w2id dictionary. Skipping this word.
# Word 'جوي' not found in w2id dictionary. Skipping this word.
# Word 'الله' not found in w2id dictionary. Skipping this word.
# Word 'تعالى' not found in w2id dictionary. Skipping this word.
# Word 'محمد' not found in w2id dictionary. Skipping this word.
# Video data for word 'رسول' not found at G:\Capstone data\karsl-502\0371. Skipping this word.
# Word 'الله' not found in w2id dictionary. Skipping this word.
# Word 'عيسى' not found in w2id dictionary. Skipping this word.
# Word 'المسيح' not found in w2id dictionary. Skipping this word.
# Word 'القرآن' not found in w2id dictionary. Skipping this word.
# Word 'الكريم' not found in w2id dictionary. Skipping this word.
# Word 'الخلفاء' not found in w2id dictionary. Skipping this word.
# Word 'الراشدون' not found in w2id dictionary. Skipping this word.
# Word 'السنة' not found in w2id dictionary. Skipping this word.
# Word 'النبوية' not found in w2id dictionary. Skipping this word.
# Word 'أركان' not found in w2id dictionary. Skipping this word.
# Word 'الإسلام' not found in w2id dictionary. Skipping this word.
# Word 'أركان' not found in w2id dictionary. Skipping this word.
# Word 'الإيمان' not found in w2id dictionary. Skipping this word.
# Video data for word 'الشهادتين' not found at G:\Capstone data\karsl-502\0364. Skipping this word.
# Word 'يصلي' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'الصلاة' not found in w2id dictionary. Skipping this word.
# Video data for word 'الزكاة' not found at G:\Capstone data\karsl-502\0366. Skipping this word.
# Video data for word 'الصوم' not found at G:\Capstone data\karsl-502\0367. Skipping this word.
# Video data for word 'العمرة' not found at G:\Capstone data\karsl-502\0368. Skipping this word.
# Video data for word 'الحج' not found at G:\Capstone data\karsl-502\0369. Skipping this word.
# Video data for word 'ملائكة' not found at G:\Capstone data\karsl-502\0370. Skipping this word.
# Video data for word 'رسول' not found at G:\Capstone data\karsl-502\0371. Skipping this word.
# Word 'يوم' not found in w2id dictionary. Skipping this word.
# Word 'القيامة' not found in w2id dictionary. Skipping this word.
# Word 'القضاء' not found in w2id dictionary. Skipping this word.
# Word 'والقدر' not found in w2id dictionary. Skipping this word.
# Word 'أركان' not found in w2id dictionary. Skipping this word.
# Word 'الصلاة' not found in w2id dictionary. Skipping this word.
# Video data for word 'خير' not found at G:\Capstone data\karsl-502\0375. Skipping this word.
# Video data for word 'النية' not found at G:\Capstone data\karsl-502\0376. Skipping this word.
# Video data for word 'شر' not found at G:\Capstone data\karsl-502\0377. Skipping this word.
# Video data for word 'طهارة' not found at G:\Capstone data\karsl-502\0378. Skipping this word.
# Word 'مبطلات' not found in w2id dictionary. Skipping this word.
# Word 'الصلاة' not found in w2id dictionary. Skipping this word.
# Video data for word 'تيمم' not found at G:\Capstone data\karsl-502\0380. Skipping this word.
# Word 'يتوضأ' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'وضوء' not found in w2id dictionary. Skipping this word.
# Video data for word 'يؤذن' not found at G:\Capstone data\karsl-502\0382. Skipping this word.
# Word 'مسح' not found in w2id dictionary. Skipping this word.
# Word 'على' not found in w2id dictionary. Skipping this word.
# Word 'الخفين' not found in w2id dictionary. Skipping this word.
# Word 'صلاة' not found in w2id dictionary. Skipping this word.
# Word 'الفجر' not found in w2id dictionary. Skipping this word.
# Word 'صلاة' not found in w2id dictionary. Skipping this word.
# Word 'الظهر' not found in w2id dictionary. Skipping this word.
# Word 'صلاة' not found in w2id dictionary. Skipping this word.
# Word 'العصر' not found in w2id dictionary. Skipping this word.
# Word 'صلاة' not found in w2id dictionary. Skipping this word.
# Word 'المغرب' not found in w2id dictionary. Skipping this word.
# Word 'صلاة' not found in w2id dictionary. Skipping this word.
# Word 'العشاء' not found in w2id dictionary. Skipping this word.
# Video data for word 'خطبة' not found at G:\Capstone data\karsl-502\0389. Skipping this word.
# Video data for word 'خطبة' not found at G:\Capstone data\karsl-502\0389. Skipping this word.
# Word 'الجمعة' not found in w2id dictionary. Skipping this word.
# Video data for word 'خطيب' not found at G:\Capstone data\karsl-502\0391. Skipping this word.
# Video data for word 'خطبة' not found at G:\Capstone data\karsl-502\0389. Skipping this word.
# Word 'العيد' not found in w2id dictionary. Skipping this word.
# Video data for word 'مسجد' not found at G:\Capstone data\karsl-502\0393. Skipping this word.
# Video data for word 'سورة' not found at G:\Capstone data\karsl-502\0394. Skipping this word.
# Video data for word 'إمام' not found at G:\Capstone data\karsl-502\0395. Skipping this word.
# Video data for word 'سورة' not found at G:\Capstone data\karsl-502\0394. Skipping this word.
# Word 'الفاتحة' not found in w2id dictionary. Skipping this word.
# Video data for word 'آية' not found at G:\Capstone data\karsl-502\0397. Skipping this word.
# Word 'ليلة' not found in w2id dictionary. Skipping this word.
# Word 'القدر' not found in w2id dictionary. Skipping this word.
# Video data for word 'عيد' not found at G:\Capstone data\karsl-502\0399. Skipping this word.
# Video data for word 'عيد' not found at G:\Capstone data\karsl-502\0399. Skipping this word.
# Word 'الفطر' not found in w2id dictionary. Skipping this word.
# Video data for word 'عيد' not found at G:\Capstone data\karsl-502\0399. Skipping this word.
# Word 'الأضحى' not found in w2id dictionary. Skipping this word.
# Video data for word 'إحرام' not found at G:\Capstone data\karsl-502\0402. Skipping this word.
# Video data for word 'مكة' not found at G:\Capstone data\karsl-502\0403. Skipping this word.
# Video data for word 'الكعبة' not found at G:\Capstone data\karsl-502\0404. Skipping this word.
# Word 'المدينة' not found in w2id dictionary. Skipping this word.
# Word 'المنورة' not found in w2id dictionary. Skipping this word.
# Video data for word 'منى' not found at G:\Capstone data\karsl-502\0406. Skipping this word.
# Word 'جبل' not found in w2id dictionary. Skipping this word.
# Word 'عرفات' not found in w2id dictionary. Skipping this word.
# Word 'الصفا' not found in w2id dictionary. Skipping this word.
# Word 'والمروة' not found in w2id dictionary. Skipping this word.
# Video data for word 'مزدلفة' not found at G:\Capstone data\karsl-502\0409. Skipping this word.
# Word 'رمي' not found in w2id dictionary. Skipping this word.
# Word 'الجمرات' not found in w2id dictionary. Skipping this word.
# Video data for word 'طواف' not found at G:\Capstone data\karsl-502\0411. Skipping this word.
# Word 'ماء' not found in w2id dictionary. Skipping this word.
# Word 'زمزم' not found in w2id dictionary. Skipping this word.
# Video data for word 'الأضحية' not found at G:\Capstone data\karsl-502\0413. Skipping this word.
# Word 'فك' not found in w2id dictionary. Skipping this word.
# Word 'الإحرام' not found in w2id dictionary. Skipping this word.
# Video data for word 'طواف' not found at G:\Capstone data\karsl-502\0411. Skipping this word.
# Word 'الوداع' not found in w2id dictionary. Skipping this word.
# Word 'المسجد' not found in w2id dictionary. Skipping this word.
# Word 'الأقصى' not found in w2id dictionary. Skipping this word.
# Video data for word 'يسبح' not found at G:\Capstone data\karsl-502\0417. Skipping this word.
# Word 'الحمد' not found in w2id dictionary. Skipping this word.
# Word 'لله' not found in w2id dictionary. Skipping this word.
# Word 'سبحان' not found in w2id dictionary. Skipping this word.
# Word 'الله' not found in w2id dictionary. Skipping this word.
# Video data for word 'إيمان' not found at G:\Capstone data\karsl-502\0420. Skipping this word.
# Word 'الشرك' not found in w2id dictionary. Skipping this word.
# Word 'بالله' not found in w2id dictionary. Skipping this word.
# Word 'أعوذ' not found in w2id dictionary. Skipping this word.
# Word 'بالله' not found in w2id dictionary. Skipping this word.
# Video data for word 'شيطان' not found at G:\Capstone data\karsl-502\0423. Skipping this word.
# Video data for word 'جن' not found at G:\Capstone data\karsl-502\0424. Skipping this word.
# Video data for word 'الضالون' not found at G:\Capstone data\karsl-502\0425. Skipping this word.
# Word 'المغضوب' not found in w2id dictionary. Skipping this word.
# Word 'عليهم' not found in w2id dictionary. Skipping this word.
# Video data for word 'صنم' not found at G:\Capstone data\karsl-502\0427. Skipping this word.
# Video data for word 'زنى' not found at G:\Capstone data\karsl-502\0428. Skipping this word.
# Video data for word 'الجنة' not found at G:\Capstone data\karsl-502\0429. Skipping this word.
# Video data for word 'النار' not found at G:\Capstone data\karsl-502\0430. Skipping this word.
# Video data for word 'روح' not found at G:\Capstone data\karsl-502\0431. Skipping this word.
# Video data for word 'حقوق' not found at G:\Capstone data\karsl-502\0432. Skipping this word.
# Video data for word 'واجبات' not found at G:\Capstone data\karsl-502\0433. Skipping this word.
# Video data for word 'حسنات' not found at G:\Capstone data\karsl-502\0434. Skipping this word.
# Video data for word 'سيئات' not found at G:\Capstone data\karsl-502\0435. Skipping this word.
# Video data for word 'حلال' not found at G:\Capstone data\karsl-502\0436. Skipping this word.
# Video data for word 'حرام' not found at G:\Capstone data\karsl-502\0437. Skipping this word.
# Video data for word 'مغفرة' not found at G:\Capstone data\karsl-502\0438. Skipping this word.
# Video data for word 'دين' not found at G:\Capstone data\karsl-502\0439. Skipping this word.
# Video data for word 'مسيحي' not found at G:\Capstone data\karsl-502\0440. Skipping this word.
# Video data for word 'يهودي' not found at G:\Capstone data\karsl-502\0441. Skipping this word.
# Video data for word 'كنيسة' not found at G:\Capstone data\karsl-502\0442. Skipping this word.
# Word 'إسراء' not found in w2id dictionary. Skipping this word.
# Word 'ومعراج' not found in w2id dictionary. Skipping this word.
# Video data for word 'حواء' not found at G:\Capstone data\karsl-502\0444. Skipping this word.
# Video data for word 'آدم' not found at G:\Capstone data\karsl-502\0445. Skipping this word.
# Video data for word 'صدقة' not found at G:\Capstone data\karsl-502\0446. Skipping this word.
# Video data for word 'نبي' not found at G:\Capstone data\karsl-502\0447. Skipping this word.
# Video data for word 'هداية' not found at G:\Capstone data\karsl-502\0448. Skipping this word.
# Video data for word 'أمانة' not found at G:\Capstone data\karsl-502\0449. Skipping this word.
# Video data for word 'شهيد' not found at G:\Capstone data\karsl-502\0450. Skipping this word.
# Video data for word 'حقوق' not found at G:\Capstone data\karsl-502\0432. Skipping this word.
# Word 'الوالدين' not found in w2id dictionary. Skipping this word.
# Word 'عقوق' not found in w2id dictionary. Skipping this word.
# Word 'الوالدين' not found in w2id dictionary. Skipping this word.
# Video data for word 'مسلم' not found at G:\Capstone data\karsl-502\0453. Skipping this word.
# Video data for word 'رحمة' not found at G:\Capstone data\karsl-502\0454. Skipping this word.
# Video data for word 'عيد' not found at G:\Capstone data\karsl-502\0399. Skipping this word.
# Word 'رأس' not found in w2id dictionary. Skipping this word.
# Word 'السنة' not found in w2id dictionary. Skipping this word.
# Video data for word 'فروض' not found at G:\Capstone data\karsl-502\0456. Skipping this word.
# Word 'قبة' not found in w2id dictionary. Skipping this word.
# Word 'الصخرة' not found in w2id dictionary. Skipping this word.
# Video data for word 'خلق' not found at G:\Capstone data\karsl-502\0458. Skipping this word.
# Video data for word 'مهندس' not found at G:\Capstone data\karsl-502\0459. Skipping this word.
# Word 'مصور' not found in w2id dictionary. Skipping this word.
# Word 'فوتوغرافي' not found in w2id dictionary. Skipping this word.
# Word 'جزار' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'قصاب' not found in w2id dictionary. Skipping this word.
# Video data for word 'سائق' not found at G:\Capstone data\karsl-502\0462. Skipping this word.
# Video data for word 'صائغ' not found at G:\Capstone data\karsl-502\0463. Skipping this word.
# Video data for word 'خادم' not found at G:\Capstone data\karsl-502\0464. Skipping this word.
# Word 'رئيس' not found in w2id dictionary. Skipping this word.
# Word 'قسم' not found in w2id dictionary. Skipping this word.
# Video data for word 'حداد' not found at G:\Capstone data\karsl-502\0466. Skipping this word.
# Word 'لحام' not found in w2id dictionary. Skipping this word.
# Word 'كهربائي' not found in w2id dictionary. Skipping this word.
# Word 'مترجم' not found in w2id dictionary. Skipping this word.
# Word 'لغة' not found in w2id dictionary. Skipping this word.
# Word 'الإشارة' not found in w2id dictionary. Skipping this word.
# Video data for word 'مذيع' not found at G:\Capstone data\karsl-502\0469. Skipping this word.
# Word 'مترجم' not found in w2id dictionary. Skipping this word.
# Word 'لغات' not found in w2id dictionary. Skipping this word.
# Video data for word 'مدير' not found at G:\Capstone data\karsl-502\0471. Skipping this word.
# Video data for word 'سفير' not found at G:\Capstone data\karsl-502\0472. Skipping this word.
# Video data for word 'وزير' not found at G:\Capstone data\karsl-502\0473. Skipping this word.
# Word 'ملك' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'سلطان' not found in w2id dictionary. Skipping this word.
# Word 'أمير' not found in w2id dictionary. Skipping this word.
# Word 'البلاد' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'رئيس' not found in w2id dictionary. Skipping this word.
# Word 'الجمهورية' not found in w2id dictionary. Skipping this word.
# Video data for word 'شيخ' not found at G:\Capstone data\karsl-502\0476. Skipping this word.
# Word 'محافظ' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'وال' not found in w2id dictionary. Skipping this word.
# Word 'ولي' not found in w2id dictionary. Skipping this word.
# Word 'عهد' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'وكيل' not found in w2id dictionary. Skipping this word.
# Word 'وزارة' not found in w2id dictionary. Skipping this word.
# Word 'رئيس' not found in w2id dictionary. Skipping this word.
# Word 'مجلس' not found in w2id dictionary. Skipping this word.
# Word 'الشعب' not found in w2id dictionary. Skipping this word.
# Word '(النواب)' not found in w2id dictionary. Skipping this word.
# Word 'أمين' not found in w2id dictionary. Skipping this word.
# Word 'عام' not found in w2id dictionary. Skipping this word.
# Video data for word 'صحفي' not found at G:\Capstone data\karsl-502\0481. Skipping this word.
# Video data for word 'رسام' not found at G:\Capstone data\karsl-502\0482. Skipping this word.
# Word 'خياط' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'تارزي' not found in w2id dictionary. Skipping this word.
# Video data for word 'ضابط' not found at G:\Capstone data\karsl-502\0484. Skipping this word.
# Video data for word 'طيار' not found at G:\Capstone data\karsl-502\0485. Skipping this word.
# Video data for word 'جندي' not found at G:\Capstone data\karsl-502\0486. Skipping this word.
# Video data for word 'حلاق' not found at G:\Capstone data\karsl-502\0487. Skipping this word.
# Video data for word 'صباغ' not found at G:\Capstone data\karsl-502\0488. Skipping this word.
# Video data for word 'رجل' not found at G:\Capstone data\karsl-502\0202. Skipping this word.
# Word 'إطفاء' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'دفاع' not found in w2id dictionary. Skipping this word.
# Word 'مدني' not found in w2id dictionary. Skipping this word.
# Video data for word 'نجار' not found at G:\Capstone data\karsl-502\0490. Skipping this word.
# Word 'معلم' not found in w2id dictionary. Skipping this word.
# Word '/' not found in w2id dictionary. Skipping this word.
# Word 'مدرس' not found in w2id dictionary. Skipping this word.
# Video data for word 'طباخ' not found at G:\Capstone data\karsl-502\0492. Skipping this word.
# Video data for word 'فلاح' not found at G:\Capstone data\karsl-502\0493. Skipping this word.
# Video data for word 'موظف' not found at G:\Capstone data\karsl-502\0494. Skipping this word.
# Word 'أمين' not found in w2id dictionary. Skipping this word.
# Word 'صندوق' not found in w2id dictionary. Skipping this word.
# Video data for word 'صيدلي' not found at G:\Capstone data\karsl-502\0496. Skipping this word.
# Video data for word 'طبيب' not found at G:\Capstone data\karsl-502\0497. Skipping this word.
# Video data for word 'ممرضة' not found at G:\Capstone data\karsl-502\0498. Skipping this word.
# Video data for word 'ممرض' not found at G:\Capstone data\karsl-502\0499. Skipping this word.
# Video data for word 'محام' not found at G:\Capstone data\karsl-502\0500. Skipping this word.
# Video data for word 'انتقال' not found at G:\Capstone data\karsl-502\0501. Skipping this word.
# Video data for word 'تعيين' not found at G:\Capstone data\karsl-502\0502. Skipping this word.
# Error: No valid data found after processing!
# Error: Empty training data. Please check the input data.

# %% [markdown]
# train the LSTM model using the prepared training data (X_train, y_train) and validation data (X_val, y_val).

# %% [markdown]
# The model is trained with a specified number of epochs and batch size.
# NOTE THAT FOR >> Early Stopping: We use early stopping to prevent overfitting by monitoring the validation loss.

# %%
# Define input shape based on the data
input_shape = X_train.shape[1:]

# Define the number of classes (unique sentences)
num_classes = len(label_map)

# Build and compile the LSTM model
model = build_lstm_model(input_shape, num_classes)

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32,
                    validation_data=(X_val, y_val),
                    callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# C:\Users\UNKN0VVlV\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       5 num_classes = len(label_map)
#       7 # Build and compile the LSTM model
# ----> 8 model = build_lstm_model(input_shape, num_classes)
#      10 # Train the model
#      11 history = model.fit(X_train, y_train, epochs=30, batch_size=32,
#      12                     validation_data=(X_val, y_val),
#      13                     callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
#
# Cell In[16], line 3, in build_lstm_model(input_shape, num_classes)
#       1 def build_lstm_model(input_shape, num_classes):
#       2     model = Sequential()
# ----> 3     model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape))
#       4     model.add(LSTM(128))  # Process the entire sentence as a sequence of words
#       5     model.add(Dense(64, activation='relu'))  # Dense layer for hidden representation
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\sequential.py:122, in Sequential.add(self, layer, rebuild)
#     120 self._layers.append(layer)
#     121 if rebuild:
# --> 122     self._maybe_rebuild()
#     123 else:
#     124     self.built = False
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\sequential.py:149, in Sequential._maybe_rebuild(self)
#     147 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     148     input_shape = self._layers[0].batch_shape
# --> 149     self.build(input_shape)
#     150 elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     151     # We can build the Sequential model if the first layer has the
#     152     # `input_shape` property. This is most commonly found in Functional
#     153     # model.
#     154     input_shape = self._layers[0].input_shape
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:230, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     228 with obj._open_name_scope():
#     229     obj._path = current_path()
# --> 230     original_build_method(*args, **kwargs)
#     231 # Record build config.
#     232 signature = inspect.signature(original_build_method)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\sequential.py:195, in Sequential.build(self, input_shape)
#     193 for layer in self._layers[1:]:
#     194     try:
# --> 195         x = layer(x)
#     196     except NotImplementedError:
#     197         # Can happen if shape inference is not implemented.
#     198         # TODO: consider reverting inbound nodes on layers processed.
#     199         return
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185     if ndim != spec.ndim:
# --> 186         raise ValueError(
#     187             f'Input {input_index} of layer "{layer_name}" '
#     188             "is incompatible with the layer: "
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     190             f"Full shape received: {shape}"
#     191         )
#     192 if spec.max_ndim is not None:
#     193     if ndim is not None and ndim > spec.max_ndim:
#
# ValueError: Input 0 of layer "bidirectional" is incompatible with the layer: expected ndim=3, found ndim=1. Full shape received: (None,)

# %% [markdown]
# Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')

# %% [markdown]
# **>> eypoint Extraction:**
# Use extract_keypoints_from_video to process the videos and return sequences of keypoints for each word in a sentence.
#
# **>> Sentence Sequences:**
# Create sequences for multiple words and concatenate them to form a full sentence sequence.
#
# **>> LSTM Model:**
# Building an LSTM model to handle sentence-level sequences.
#
# **>> Data Preparation:**
# Format the data as sequences of keypoints and sentence labels.
#
# **>> Model Training:**
# Train the model using the training set and validate it using the validation set.
#
# **>> Evaluation:**
# Evaluating the model's performance on the test set.

# %%
# Define the Bidirectional LSTM model with Attention


model = tf.keras.Sequential([
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(words), activation='softmax')
])

# Compile the model

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Set up early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Metric to monitor for early stopping
    mode='min',  # Set mode to 'min' for minimizing the metric
    patience=5,  # Number of epochs with no improvement before stopping
    restore_best_weights=True,  # Restore the best model weights
    verbose=1
)


model_training_history = model.fit(X_train, y_train, batch_size=32, validation_data=(X_val,y_val), validation_batch_size=32, epochs=50, callbacks=[early_stopping])


# Evaluate the model on train data
model_evaluation_history = model.evaluate(X_train, y_train)


# Evaluate the model on test data
model_evaluation_history = model.evaluate(X_test, y_test)



def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()



# Visualize the training and validation loss metrices.
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')


#Predicted sign
res = model.predict(X_test)
words[np.argmax(res[1])]


#Real sign
words[np.argmax(y_test[1])]



# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'Kaleem_model_2_signers___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save your Model.
model.save(model_file_name)


def get_key_by_value(dictionary, value):
    for key, val in dictionary.items():
        if val == value:
            return key
    return None



ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

y = []
for v in ytrue:
    y.append(get_key_by_value(label_map, v))
print(y)


y = [karsl_6[karsl_6['Sign-Arabic'] == v]['Sign-English'].values[0] for v in y]
print(y)



ypred = []
for v in yhat:
    ypred.append(get_key_by_value(label_map, v))
print(ypred)



ypred = [karsl_6[karsl_6['Sign-Arabic'] == v]['Sign-English'].values[0] for v in ypred]
print(ypred)





from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming y and ypred are your target labels and predicted labels, respectively

# Select the first 20 classes
y_subset = y[:200]
ypred_subset = ypred[:200]

# Get unique class labels
class_labels = np.unique(y_subset)

# Compute confusion matrix
cm = confusion_matrix(y_subset, ypred_subset, labels=class_labels)

# Create a DataFrame from the confusion matrix
df_cm = pd.DataFrame(cm, index=class_labels, columns=class_labels)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.3)  # for label size
sns.heatmap(df_cm, cmap="Blues", annot=True, fmt="d", annot_kws={"size": 12})
plt.title("Confusion Matrix - First 20 Classes")
plt.show()
